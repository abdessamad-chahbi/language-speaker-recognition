# %% [markdown]
# # Objectif
# Ce fichier a pour objectif de préparer les données pour **la reconnaissance du locuteur (Partie II)** en utilisant les caractéristiques MFCC extraites et réorganisées à l'aide du fichier **Part2_R-Locuteur_MFCC-Extraction.ipynb**. Le processus commence par le chargement des données depuis le dossier "**Features_MFCC_Locuteur**", où elles sont organisées selon la langue, le genre du locuteur, l'identifiant du locuteur, et le type (entraînement/test).
#
# Par la suite, des modèles de Mélanges de Gaussiennes (GMM) seront générés et entraînés pour chaque locuteur à partir de ces caractéristiques. Enfin, ces modèles seront sauvegardés pour une utilisation ultérieure,

# %%
# !pip install python_speech_features

# %%
import numpy as np
import os
import scipy.io.wavfile as wav
from python_speech_features import mfcc
from sklearn.mixture import GaussianMixture
from datetime import datetime
from joblib import dump
from joblib import load

from google.colab import drive
drive.mount('/content/drive') # Monter (Mount) Google Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# - Chargement des données MFCC pour Locuteur sauvegardées

# %%
# Chemin vers le dossier MFCC de Locuteur dans Google Drive
mfcc_locuteur_dir = '/content/drive/My Drive/Reconnaissance/Features_MFCC_Locuteur'

langues = os.listdir(mfcc_locuteur_dir)
print(langues)
# Out:
# ['French', 'arabic', 'Japanese', 'Spanish', 'English']

# %% [markdown]
# - Charge les caractéristiques MFCC pour un locuteur spécifique à partir des données d'entraînement.

# %%
def charger_caracteristiques_mfcc_train_par_locuteur(repertoire_mfcc, langue_cible, genre_cible, locuteur_cible):
    # Liste vide pour stocker les caractéristiques MFCC
    donnees_mfcc_entraine = []

    # Chemin vers le dossier contenant les fichiers MFCC pour l'ensemble train
    dossier_train = os.path.join(repertoire_mfcc, langue_cible, genre_cible, locuteur_cible, 'train')

    # Parcours des fichiers dans le dossier d'entraînement
    for fichier_mfcc in os.listdir(dossier_train):
        # Chargement des caractéristiques MFCC à partir d'un fichier texte
        caracteristiques_mfcc = np.loadtxt(os.path.join(dossier_train, fichier_mfcc), delimiter=',')

        # Ajout des caractéristiques dans la liste des données d'entraînement
        donnees_mfcc_entraine.append(caracteristiques_mfcc)

    # Retourne les données empilées sous forme de tableau numpy
    return np.vstack(donnees_mfcc_entraine)

# %% [markdown]
# - Entraîne un modèle GMM avec les données d'entraînement et enregistre le modèle.

# %%
def entrainer_modele_GMM_par_locuteur(donnees_entraînement, nombre_composants, langue, genre, id_locuteur, dossier_sortie):
    # Affiche l'heure de début de l'entraînement
    heure_debut = datetime.now().strftime("%H:%M:%S")
    print(f'Début de l\'entraînement à : {heure_debut}')

    # Création et entraînement du modèle GMM
    modele_gmm = GaussianMixture(n_components=nombre_composants, covariance_type='full', max_iter=200, random_state=0)
    modele_gmm.fit(donnees_entraînement)

    # Affiche l'heure de fin de l'entraînement
    heure_fin = datetime.now().strftime("%H:%M:%S")
    print(f'Fin de l\'entraînement à : {heure_fin}')

    # Construction du nom du fichier avec les informations spécifiées
    nom_fichier_modele = f"GMM_{nombre_composants}_{langue}_{genre}_{id_locuteur}_Locuteur.joblib"

    # Construction du chemin complet pour sauvegarder le modèle
    chemin_complet_fichier = f"{dossier_sortie}/{nom_fichier_modele}"

    # Sauvegarde du modèle GMM
    dump(modele_gmm, chemin_complet_fichier)
    # print(f"Modèle sauvegardé sous le nom : {chemin_complet_fichier}\n")

    # Retourne le modèle GMM entraîné
    return modele_gmm

# %% [markdown]
# - Ce code effectue l'entraînement de modèles GMM pour des données audio structurées par langue, genre et locuteur.
# - Il crée une organisation hiérarchique dans un répertoire Google Drive, où les modèles GMM sont stockés dans des sous-dossiers dédiés.
# - Les étapes principales incluent :
# 1. Initialisation du dictionnaire `modeles_GMM` pour conserver les modèles GMM pour chaque combinaison langue-genre-locuteur.
# 2. Création des dossiers dans Google Drive pour chaque langue, genre et locuteur, afin de sauvegarder les modèles de manière organisée.
# 3. Chargement des données MFCC pour chaque locuteur depuis un dossier source.
# 4. Entraînement de modèles GMM avec différents nombres de composantes (par exemple : 8, 16, 32, etc.).
# 5. Sauvegarde des modèles GMM entraînés dans les dossiers correspondants pour un usage futur.

# %%
### N'exécutez pas cette cellule si les résultats sont déjà calculés et enregistrés dans Google Drive, car ce processus est long.

# Chemin vers le dossier pour stocker les modèles GMM dans Google Drive
dossier_GMMs_Locuteur = '/content/drive/My Drive/Reconnaissance/Models_GMM/R-Locuteur'
os.makedirs(dossier_GMMs_Locuteur, exist_ok=True)

# Initialisation du dictionnaire pour stocker les modèles GMM
modeles_GMM = {}

# Parcours des langues dans le dossier MFCC
langues = os.listdir(mfcc_locuteur_dir)
# langues = ['English']
print(f"Langues détectées : {langues}")

# Parcours des langues
for langue in langues:
    modeles_GMM[langue] = {}

    # Création du répertoire pour la langue dans Google Drive
    dossier_langue = os.path.join(dossier_GMMs_Locuteur, langue)
    os.makedirs(dossier_langue, exist_ok=True)

    print(f"\nDébut d'entraînement pour la langue : {langue}")

    # Parcours des genres (homme/femme) pour chaque langue
    for genre in os.listdir(os.path.join(mfcc_locuteur_dir, langue)):
        modeles_GMM[langue][genre] = {}

        # Création du répertoire pour le genre
        dossier_genre = os.path.join(dossier_langue, genre)
        os.makedirs(dossier_genre, exist_ok=True)

        print(f"Traitement du genre : {genre}")

        # Parcours des locuteurs pour chaque genre
        for locuteur in os.listdir(os.path.join(mfcc_locuteur_dir, langue, genre)):
            modeles_GMM[langue][genre][locuteur] = {}

            # Création du répertoire pour le locuteur
            dossier_locuteur = os.path.join(dossier_genre, locuteur)
            os.makedirs(dossier_locuteur, exist_ok=True)

            print(f"Locuteur : {locuteur}")

            # Chargement des données MFCC d'entraînement pour le locuteur
            donnees_train = charger_caracteristiques_mfcc_train_par_locuteur(mfcc_locuteur_dir, langue, genre, locuteur)

            # Liste des nombres de composants à tester
            liste_composants = [8, 16, 32, 64, 128]
            for nombre_composants in liste_composants:
                print(f"========= Entraînement du GMM avec {nombre_composants} composants ==========")

                # Entraînement du modèle GMM et sauvegarde
                modele_gmm = entrainer_modele_GMM_par_locuteur(donnees_train, nombre_composants, langue, genre, locuteur, dossier_locuteur)

                # Sauvegarde du modèle GMM dans le dictionnaire
                modeles_GMM[langue][genre][locuteur][nombre_composants] = modele_gmm
# Out:
# Langues détectées : ['English']
#
# Début d'entraînement pour la langue : English
# Traitement du genre : Homme
# Locuteur : H13
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 15:45:13
# Fin de l'entraînement à : 15:45:18
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 15:45:18
# Fin de l'entraînement à : 15:45:38
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 15:45:38
# Fin de l'entraînement à : 15:46:17
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 15:46:17
# Fin de l'entraînement à : 15:47:13
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 15:47:13
# Fin de l'entraînement à : 15:49:01
# Locuteur : H14
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 15:49:08
# Fin de l'entraînement à : 15:49:12
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 15:49:12
# Fin de l'entraînement à : 15:49:25
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 15:49:25
# Fin de l'entraînement à : 15:49:53
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 15:49:53
# Fin de l'entraînement à : 15:50:28
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 15:50:28
# Fin de l'entraînement à : 15:52:36
# Locuteur : H12
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 15:52:47
# Fin de l'entraînement à : 15:52:53
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 15:52:53
# Fin de l'entraînement à : 15:52:59
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 15:52:59
# Fin de l'entraînement à : 15:53:19
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 15:53:19
# Fin de l'entraînement à : 15:54:01
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 15:54:01
# Fin de l'entraînement à : 15:55:49
# Locuteur : H15
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 15:55:58
# Fin de l'entraînement à : 15:56:03
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 15:56:03
# Fin de l'entraînement à : 15:56:19
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 15:56:19
# Fin de l'entraînement à : 15:57:00
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 15:57:00
# Fin de l'entraînement à : 15:57:48
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 15:57:48
# Fin de l'entraînement à : 16:00:08
# Locuteur : H16
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:00:18
# Fin de l'entraînement à : 16:00:23
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:00:23
# Fin de l'entraînement à : 16:00:37
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:00:37
# Fin de l'entraînement à : 16:01:04
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:01:04
# Fin de l'entraînement à : 16:02:03
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:02:03
# Fin de l'entraînement à : 16:03:54
# Locuteur : H17
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:04:03
# Fin de l'entraînement à : 16:04:12
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:04:12
# Fin de l'entraînement à : 16:04:25
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:04:25
# Fin de l'entraînement à : 16:04:45
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:04:45
# Fin de l'entraînement à : 16:05:29
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:05:29
# Fin de l'entraînement à : 16:07:07
# Locuteur : H18
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:07:12
# Fin de l'entraînement à : 16:07:22
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:07:22
# Fin de l'entraînement à : 16:07:35
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:07:35
# Fin de l'entraînement à : 16:07:55
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:07:55
# Fin de l'entraînement à : 16:08:39
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:08:39
# Fin de l'entraînement à : 16:10:40
# Locuteur : H19
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:10:49
# Fin de l'entraînement à : 16:11:00
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:11:00
# Fin de l'entraînement à : 16:11:12
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:11:12
# Fin de l'entraînement à : 16:11:48
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:11:48
# Fin de l'entraînement à : 16:12:42
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:12:42
# Fin de l'entraînement à : 16:14:50
# Locuteur : H2
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:14:59
# Fin de l'entraînement à : 16:15:12
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:15:12
# Fin de l'entraînement à : 16:15:21
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:15:21
# Fin de l'entraînement à : 16:15:48
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:15:48
# Fin de l'entraînement à : 16:16:41
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:16:41
# Fin de l'entraînement à : 16:18:39
# Locuteur : H3
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:18:48
# Fin de l'entraînement à : 16:18:55
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:18:55
# Fin de l'entraînement à : 16:19:14
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:19:14
# Fin de l'entraînement à : 16:19:46
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:19:46
# Fin de l'entraînement à : 16:20:46
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:20:46
# Fin de l'entraînement à : 16:22:18
# Locuteur : H4
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:22:27
# Fin de l'entraînement à : 16:22:32
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:22:32
# Fin de l'entraînement à : 16:22:53
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:22:53
# Fin de l'entraînement à : 16:23:21
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:23:21
# Fin de l'entraînement à : 16:24:04
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:24:04
# Fin de l'entraînement à : 16:25:52
# Locuteur : H6
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:25:59
# Fin de l'entraînement à : 16:26:04
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:26:04
# Fin de l'entraînement à : 16:26:16
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:26:16
# Fin de l'entraînement à : 16:26:45
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:26:45
# Fin de l'entraînement à : 16:27:38
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:27:38
# Fin de l'entraînement à : 16:29:15
# Locuteur : H5
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:29:25
# Fin de l'entraînement à : 16:29:31
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:29:31
# Fin de l'entraînement à : 16:29:49
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:29:49
# Fin de l'entraînement à : 16:30:10
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:30:10
# Fin de l'entraînement à : 16:31:23
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:31:23
# Fin de l'entraînement à : 16:32:59
# Locuteur : H7
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:33:11
# Fin de l'entraînement à : 16:33:18
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:33:18
# Fin de l'entraînement à : 16:33:37
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:33:37
# Fin de l'entraînement à : 16:34:10
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:34:10
# Fin de l'entraînement à : 16:35:24
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:35:24
# Fin de l'entraînement à : 16:37:17
# Locuteur : H8
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:37:23
# Fin de l'entraînement à : 16:37:29
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:37:29
# Fin de l'entraînement à : 16:37:45
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:37:45
# Fin de l'entraînement à : 16:38:07
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:38:07
# Fin de l'entraînement à : 16:38:54
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:38:54
# Fin de l'entraînement à : 16:41:00
# Locuteur : H9
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:41:06
# Fin de l'entraînement à : 16:41:10
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:41:10
# Fin de l'entraînement à : 16:41:23
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:41:23
# Fin de l'entraînement à : 16:42:08
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:42:08
# Fin de l'entraînement à : 16:43:15
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:43:15
# Fin de l'entraînement à : 16:45:20
# Locuteur : H1
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:45:28
# Fin de l'entraînement à : 16:45:31
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:45:31
# Fin de l'entraînement à : 16:45:39
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:45:39
# Fin de l'entraînement à : 16:46:02
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:46:02
# Fin de l'entraînement à : 16:46:40
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:46:40
# Fin de l'entraînement à : 16:48:21
# Locuteur : H11
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:48:28
# Fin de l'entraînement à : 16:48:43
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:48:43
# Fin de l'entraînement à : 16:48:52
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:48:52
# Fin de l'entraînement à : 16:49:17
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:49:17
# Fin de l'entraînement à : 16:50:05
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:50:05
# Fin de l'entraînement à : 16:52:21
# Locuteur : H10
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:52:26
# Fin de l'entraînement à : 16:52:31
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:52:31
# Fin de l'entraînement à : 16:52:41
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:52:41
# Fin de l'entraînement à : 16:53:05
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:53:05
# Fin de l'entraînement à : 16:53:52
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:53:52
# Fin de l'entraînement à : 16:55:45
# Traitement du genre : Femme
# Locuteur : F12
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:55:53
# Fin de l'entraînement à : 16:55:59
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:55:59
# Fin de l'entraînement à : 16:56:14
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:56:14
# Fin de l'entraînement à : 16:56:36
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 16:56:36
# Fin de l'entraînement à : 16:57:34
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 16:57:34
# Fin de l'entraînement à : 16:59:14
# Locuteur : F11
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 16:59:20
# Fin de l'entraînement à : 16:59:25
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 16:59:25
# Fin de l'entraînement à : 16:59:42
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 16:59:42
# Fin de l'entraînement à : 17:00:06
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:00:06
# Fin de l'entraînement à : 17:00:53
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:00:53
# Fin de l'entraînement à : 17:02:42
# Locuteur : F13
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:02:52
# Fin de l'entraînement à : 17:02:56
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:02:56
# Fin de l'entraînement à : 17:03:09
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:03:09
# Fin de l'entraînement à : 17:03:35
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:03:35
# Fin de l'entraînement à : 17:04:19
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:04:19
# Fin de l'entraînement à : 17:06:02
# Locuteur : F14
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:06:09
# Fin de l'entraînement à : 17:06:13
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:06:13
# Fin de l'entraînement à : 17:06:21
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:06:21
# Fin de l'entraînement à : 17:06:53
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:06:53
# Fin de l'entraînement à : 17:07:45
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:07:45
# Fin de l'entraînement à : 17:09:51
# Locuteur : F15
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:10:02
# Fin de l'entraînement à : 17:10:08
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:10:08
# Fin de l'entraînement à : 17:10:20
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:10:20
# Fin de l'entraînement à : 17:10:52
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:10:52
# Fin de l'entraînement à : 17:11:43
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:11:43
# Fin de l'entraînement à : 17:13:21
# Locuteur : F16
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:13:30
# Fin de l'entraînement à : 17:13:38
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:13:38
# Fin de l'entraînement à : 17:13:59
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:13:59
# Fin de l'entraînement à : 17:14:23
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:14:23
# Fin de l'entraînement à : 17:15:07
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:15:07
# Fin de l'entraînement à : 17:16:53
# Locuteur : F17
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:17:01
# Fin de l'entraînement à : 17:17:08
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:17:08
# Fin de l'entraînement à : 17:17:18
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:17:18
# Fin de l'entraînement à : 17:17:36
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:17:36
# Fin de l'entraînement à : 17:18:13
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:18:13
# Fin de l'entraînement à : 17:20:30
# Locuteur : F18
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:20:39
# Fin de l'entraînement à : 17:20:51
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:20:51
# Fin de l'entraînement à : 17:21:13
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:21:13
# Fin de l'entraînement à : 17:21:35
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:21:35
# Fin de l'entraînement à : 17:22:18
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:22:18
# Fin de l'entraînement à : 17:24:12
# Locuteur : F19
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:24:19
# Fin de l'entraînement à : 17:24:23
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:24:23
# Fin de l'entraînement à : 17:24:37
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:24:37
# Fin de l'entraînement à : 17:25:05
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:25:05
# Fin de l'entraînement à : 17:25:51
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:25:51
# Fin de l'entraînement à : 17:27:36
# Locuteur : F2
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:27:44
# Fin de l'entraînement à : 17:27:50
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:27:50
# Fin de l'entraînement à : 17:28:06
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:28:06
# Fin de l'entraînement à : 17:28:43
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:28:43
# Fin de l'entraînement à : 17:29:28
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:29:28
# Fin de l'entraînement à : 17:31:13
# Locuteur : F20
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:31:18
# Fin de l'entraînement à : 17:31:26
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:31:26
# Fin de l'entraînement à : 17:31:45
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:31:45
# Fin de l'entraînement à : 17:32:07
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:32:07
# Fin de l'entraînement à : 17:33:00
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:33:00
# Fin de l'entraînement à : 17:34:37
# Locuteur : F21
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:34:49
# Fin de l'entraînement à : 17:34:55
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:34:55
# Fin de l'entraînement à : 17:35:12
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:35:12
# Fin de l'entraînement à : 17:35:31
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:35:31
# Fin de l'entraînement à : 17:36:08
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:36:08
# Fin de l'entraînement à : 17:37:35
# Locuteur : F3
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:37:45
# Fin de l'entraînement à : 17:37:54
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:37:54
# Fin de l'entraînement à : 17:38:08
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:38:08
# Fin de l'entraînement à : 17:38:31
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:38:31
# Fin de l'entraînement à : 17:39:28
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:39:28
# Fin de l'entraînement à : 17:41:19
# Locuteur : F4
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:41:28
# Fin de l'entraînement à : 17:41:34
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:41:34
# Fin de l'entraînement à : 17:41:48
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:41:48
# Fin de l'entraînement à : 17:42:15
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:42:15
# Fin de l'entraînement à : 17:43:13
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:43:13
# Fin de l'entraînement à : 17:44:49
# Locuteur : F5
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:44:58
# Fin de l'entraînement à : 17:45:06
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:45:06
# Fin de l'entraînement à : 17:45:19
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:45:19
# Fin de l'entraînement à : 17:45:43
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:45:43
# Fin de l'entraînement à : 17:46:47
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:46:47
# Fin de l'entraînement à : 17:49:07
# Locuteur : F7
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:49:19
# Fin de l'entraînement à : 17:49:30
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:49:30
# Fin de l'entraînement à : 17:49:48
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:49:48
# Fin de l'entraînement à : 17:50:24
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:50:24
# Fin de l'entraînement à : 17:51:12
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:51:12
# Fin de l'entraînement à : 17:53:01
# Locuteur : F6
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:53:08
# Fin de l'entraînement à : 17:53:17
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:53:17
# Fin de l'entraînement à : 17:53:31
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:53:31
# Fin de l'entraînement à : 17:53:55
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:53:55
# Fin de l'entraînement à : 17:54:46
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:54:46
# Fin de l'entraînement à : 17:56:32
# Locuteur : F8
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 17:56:42
# Fin de l'entraînement à : 17:56:56
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 17:56:56
# Fin de l'entraînement à : 17:57:13
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 17:57:13
# Fin de l'entraînement à : 17:57:38
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 17:57:38
# Fin de l'entraînement à : 17:58:28
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 17:58:28
# Fin de l'entraînement à : 17:59:56
# Locuteur : F9
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 18:00:04
# Fin de l'entraînement à : 18:00:15
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 18:00:15
# Fin de l'entraînement à : 18:00:32
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 18:00:32
# Fin de l'entraînement à : 18:01:09
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 18:01:09
# Fin de l'entraînement à : 18:01:48
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 18:01:48
# Fin de l'entraînement à : 18:03:37
# Locuteur : F1
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 18:03:45
# Fin de l'entraînement à : 18:03:50
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 18:03:50
# Fin de l'entraînement à : 18:04:06
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 18:04:06
# Fin de l'entraînement à : 18:04:27
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 18:04:28
# Fin de l'entraînement à : 18:05:10
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 18:05:10
# Fin de l'entraînement à : 18:06:47
# Locuteur : F10
# ========= Entraînement du GMM avec 8 composants ==========
# Début de l'entraînement à : 18:06:54
# Fin de l'entraînement à : 18:07:05
# ========= Entraînement du GMM avec 16 composants ==========
# Début de l'entraînement à : 18:07:05
# Fin de l'entraînement à : 18:07:13
# ========= Entraînement du GMM avec 32 composants ==========
# Début de l'entraînement à : 18:07:13
# Fin de l'entraînement à : 18:07:41
# ========= Entraînement du GMM avec 64 composants ==========
# Début de l'entraînement à : 18:07:41
# Fin de l'entraînement à : 18:08:29
# ========= Entraînement du GMM avec 128 composants ==========
# Début de l'entraînement à : 18:08:29
# Fin de l'entraînement à : 18:10:32

# %% [markdown]
# - Cette fonction charge les caractéristiques MFCC pour les fichiers de test d'un locuteur spécifique.
# - Elle parcourt les fichiers dans le dossier 'test' associé à un locuteur donné,
# - charge les caractéristiques MFCC de chaque fichier, et les stocke dans une liste.

# %%
# Charge les caractéristiques MFCC pour les fichiers de test d'un locuteur spécifique.
def charger_caracteristiques_mfcc_test_par_locuteur(repertoire_mfcc, langue_cible, genre_cible, locuteur_cible):
    # Liste vide pour stocker les caractéristiques MFCC
    donnees_mfcc_test = []
    noms_segments = []  # Liste pour stocker les noms des segments

    # Chemin vers le dossier contenant les fichiers MFCC pour l'ensemble test
    dossier_test = os.path.join(repertoire_mfcc, langue_cible, genre_cible, locuteur_cible, 'test')

    # Parcours des fichiers dans le dossier de test
    for fichier_mfcc in os.listdir(dossier_test):
        # Chargement des caractéristiques MFCC à partir d'un fichier texte
        caracteristiques_mfcc = np.loadtxt(os.path.join(dossier_test, fichier_mfcc), delimiter=',')

        # Ajout des caractéristiques dans la liste des données de test
        donnees_mfcc_test.append(caracteristiques_mfcc)

        # Ajout du nom du fichier (segment) à la liste des segments
        noms_segments.append(fichier_mfcc)

    # Retourne les noms des segments et les données MFCC
    return noms_segments, donnees_mfcc_test

# %%
### N'exécutez pas cette cellule si les résultats sont déjà calculés et enregistrés dans Google Drive, car ce processus est long.

# Chemin vers le dossier contenant les modèles GMM pour les locuteurs
models_save_path = '/content/drive/My Drive/Reconnaissance/Models_GMM/R-Locuteur'
# Chemin pour stocker les résultats
results_save_path = '/content/drive/My Drive/Reconnaissance/Results_GMM/R-Locuteur'
# Chemin pour les données de test
MFCC_folder = '/content/drive/My Drive/Reconnaissance/Features_MFCC_Locuteur'
langues = os.listdir(MFCC_folder)
langues = ['English']

# Liste des nombres de composants GMM à tester
liste_nb_composants = [8, 16, 32, 64, 128]

# Évaluation pour chaque nombre de composants et chaque locuteur
for n_components in liste_nb_composants:
    print(f"Évaluation des modèles avec {n_components} composants.")

    # Parcours des langues
    for langue_cible in langues:
        # Parcours des genres (homme/femme)
        for genre_cible in os.listdir(os.path.join(MFCC_folder, langue_cible)):
            # Parcours des locuteurs
            for locuteur_cible in os.listdir(os.path.join(MFCC_folder, langue_cible, genre_cible)):
                print(f"Évaluation pour le locuteur : {locuteur_cible} ({langue_cible} - {genre_cible})")

                # Créer le dossier pour les résultats du locuteur si nécessaire
                locuteur_results_path = os.path.join(results_save_path, langue_cible, genre_cible, locuteur_cible)
                os.makedirs(locuteur_results_path, exist_ok=True)

                # Nom du fichier de sortie pour les résultats de test, incluant la langue et le genre
                modele_file_name = os.path.join(locuteur_results_path, f"Test_GMM_{n_components}_{langue_cible}_{genre_cible}_{locuteur_cible}.txt")

                # Ouverture du fichier pour écrire les résultats
                with open(modele_file_name, 'w') as f:
                    # Écriture de l'en-tête dans le fichier
                    entete = "Segment_Nom\tLocuteur_Cible\tScore_Max\tDecision_Model"
                    f.write(entete + "\n")

                    # Chargement des données de test pour le locuteur cible
                    nom_segs, test_data = charger_caracteristiques_mfcc_test_par_locuteur(MFCC_folder, langue_cible, genre_cible, locuteur_cible)

                    # Dictionnaire pour stocker les modèles GMM
                    locuteur_models = {}

                    # Chargement des modèles GMM pour chaque locuteur
                    for langue in langues:
                        for genre in os.listdir(os.path.join(MFCC_folder, langue)):
                            for locuteur in os.listdir(os.path.join(MFCC_folder, langue, genre)):
                                model_file_path = os.path.join(models_save_path, langue, genre, locuteur, f"GMM_{n_components}_{langue}_{genre}_{locuteur}_Locuteur.joblib")
                                locuteur_models[locuteur] = load(model_file_path)

                    # Itération sur chaque exemple de test
                    for i in range(len(test_data)):
                        # Extraction de l'exemple de test et de son nom de segment
                        test_example = test_data[i]
                        seg_name = nom_segs[i]

                        # Dictionnaire pour stocker les scores des modèles
                        scores = {}

                        # Évaluation des modèles GMM
                        for locuteur in locuteur_models.keys():
                            gmm = locuteur_models[locuteur]  # Modèle GMM pour le locuteur
                            score = gmm.score(test_example)  # Calcul du score du modèle
                            scores[locuteur] = score  # Ajout du score au dictionnaire

                        # Locuteur avec le score maximal
                        max_score_locuteur = max(scores, key=scores.get)
                        max_score = scores[max_score_locuteur]  # Score maximal

                        # Décision sur la correspondance avec le locuteur cible
                        decision = "oui" if max_score_locuteur == locuteur_cible else "non"

                        # Construction de la ligne de résultat et écriture dans le fichier
                        ligne = f"{seg_name}\t{locuteur_cible}\t{max_score}\t{decision}"
                        f.write(ligne + "\n")

                # print(f"Évaluation terminée pour {n_components} composants et le locuteur {locuteur_cible}. Résultats sauvegardés dans {modele_file_name}.")
# Out:
# Évaluation des modèles avec 8 composants.
# Évaluation pour le locuteur : H13 (English - Homme)
# Évaluation pour le locuteur : H14 (English - Homme)
# Évaluation pour le locuteur : H12 (English - Homme)
# Évaluation pour le locuteur : H15 (English - Homme)
# Évaluation pour le locuteur : H16 (English - Homme)
# Évaluation pour le locuteur : H17 (English - Homme)
# Évaluation pour le locuteur : H18 (English - Homme)
# Évaluation pour le locuteur : H19 (English - Homme)
# Évaluation pour le locuteur : H2 (English - Homme)
# Évaluation pour le locuteur : H3 (English - Homme)
# Évaluation pour le locuteur : H4 (English - Homme)
# Évaluation pour le locuteur : H6 (English - Homme)
# Évaluation pour le locuteur : H5 (English - Homme)
# Évaluation pour le locuteur : H7 (English - Homme)
# Évaluation pour le locuteur : H8 (English - Homme)
# Évaluation pour le locuteur : H9 (English - Homme)
# Évaluation pour le locuteur : H1 (English - Homme)
# Évaluation pour le locuteur : H11 (English - Homme)
# Évaluation pour le locuteur : H10 (English - Homme)
# Évaluation pour le locuteur : F12 (English - Femme)
# Évaluation pour le locuteur : F11 (English - Femme)
# Évaluation pour le locuteur : F13 (English - Femme)
# Évaluation pour le locuteur : F14 (English - Femme)
# Évaluation pour le locuteur : F15 (English - Femme)
# Évaluation pour le locuteur : F16 (English - Femme)
# Évaluation pour le locuteur : F17 (English - Femme)
# Évaluation pour le locuteur : F18 (English - Femme)
# Évaluation pour le locuteur : F19 (English - Femme)
# Évaluation pour le locuteur : F2 (English - Femme)
# Évaluation pour le locuteur : F20 (English - Femme)
# Évaluation pour le locuteur : F21 (English - Femme)
# Évaluation pour le locuteur : F3 (English - Femme)
# Évaluation pour le locuteur : F4 (English - Femme)
# Évaluation pour le locuteur : F5 (English - Femme)
# Évaluation pour le locuteur : F7 (English - Femme)
# Évaluation pour le locuteur : F6 (English - Femme)
# Évaluation pour le locuteur : F8 (English - Femme)
# Évaluation pour le locuteur : F9 (English - Femme)
# Évaluation pour le locuteur : F1 (English - Femme)
# Évaluation pour le locuteur : F10 (English - Femme)
# Évaluation des modèles avec 16 composants.
# Évaluation pour le locuteur : H13 (English - Homme)
# Évaluation pour le locuteur : H14 (English - Homme)
# Évaluation pour le locuteur : H12 (English - Homme)
# Évaluation pour le locuteur : H15 (English - Homme)
# Évaluation pour le locuteur : H16 (English - Homme)
# Évaluation pour le locuteur : H17 (English - Homme)
# Évaluation pour le locuteur : H18 (English - Homme)
# Évaluation pour le locuteur : H19 (English - Homme)
# Évaluation pour le locuteur : H2 (English - Homme)
# Évaluation pour le locuteur : H3 (English - Homme)
# Évaluation pour le locuteur : H4 (English - Homme)
# Évaluation pour le locuteur : H6 (English - Homme)
# Évaluation pour le locuteur : H5 (English - Homme)
# Évaluation pour le locuteur : H7 (English - Homme)
# Évaluation pour le locuteur : H8 (English - Homme)
# Évaluation pour le locuteur : H9 (English - Homme)
# Évaluation pour le locuteur : H1 (English - Homme)
# Évaluation pour le locuteur : H11 (English - Homme)
# Évaluation pour le locuteur : H10 (English - Homme)
# Évaluation pour le locuteur : F12 (English - Femme)
# Évaluation pour le locuteur : F11 (English - Femme)
# Évaluation pour le locuteur : F13 (English - Femme)
# Évaluation pour le locuteur : F14 (English - Femme)
# Évaluation pour le locuteur : F15 (English - Femme)
# Évaluation pour le locuteur : F16 (English - Femme)
# Évaluation pour le locuteur : F17 (English - Femme)
# Évaluation pour le locuteur : F18 (English - Femme)
# Évaluation pour le locuteur : F19 (English - Femme)
# Évaluation pour le locuteur : F2 (English - Femme)
# Évaluation pour le locuteur : F20 (English - Femme)
# Évaluation pour le locuteur : F21 (English - Femme)
# Évaluation pour le locuteur : F3 (English - Femme)
# Évaluation pour le locuteur : F4 (English - Femme)
# Évaluation pour le locuteur : F5 (English - Femme)
# Évaluation pour le locuteur : F7 (English - Femme)
# Évaluation pour le locuteur : F6 (English - Femme)
# Évaluation pour le locuteur : F8 (English - Femme)
# Évaluation pour le locuteur : F9 (English - Femme)
# Évaluation pour le locuteur : F1 (English - Femme)
# Évaluation pour le locuteur : F10 (English - Femme)
# Évaluation des modèles avec 32 composants.
# Évaluation pour le locuteur : H13 (English - Homme)
# Évaluation pour le locuteur : H14 (English - Homme)
# Évaluation pour le locuteur : H12 (English - Homme)
# Évaluation pour le locuteur : H15 (English - Homme)
# Évaluation pour le locuteur : H16 (English - Homme)
# Évaluation pour le locuteur : H17 (English - Homme)
# Évaluation pour le locuteur : H18 (English - Homme)
# Évaluation pour le locuteur : H19 (English - Homme)
# Évaluation pour le locuteur : H2 (English - Homme)
# Évaluation pour le locuteur : H3 (English - Homme)
# Évaluation pour le locuteur : H4 (English - Homme)
# Évaluation pour le locuteur : H6 (English - Homme)
# Évaluation pour le locuteur : H5 (English - Homme)
# Évaluation pour le locuteur : H7 (English - Homme)
# Évaluation pour le locuteur : H8 (English - Homme)
# Évaluation pour le locuteur : H9 (English - Homme)
# Évaluation pour le locuteur : H1 (English - Homme)
# Évaluation pour le locuteur : H11 (English - Homme)
# Évaluation pour le locuteur : H10 (English - Homme)
# Évaluation pour le locuteur : F12 (English - Femme)
# Évaluation pour le locuteur : F11 (English - Femme)
# Évaluation pour le locuteur : F13 (English - Femme)
# Évaluation pour le locuteur : F14 (English - Femme)
# Évaluation pour le locuteur : F15 (English - Femme)
# Évaluation pour le locuteur : F16 (English - Femme)
# Évaluation pour le locuteur : F17 (English - Femme)
# Évaluation pour le locuteur : F18 (English - Femme)
# Évaluation pour le locuteur : F19 (English - Femme)
# Évaluation pour le locuteur : F2 (English - Femme)
# Évaluation pour le locuteur : F20 (English - Femme)
# Évaluation pour le locuteur : F21 (English - Femme)
# Évaluation pour le locuteur : F3 (English - Femme)
# Évaluation pour le locuteur : F4 (English - Femme)
# Évaluation pour le locuteur : F5 (English - Femme)
# Évaluation pour le locuteur : F7 (English - Femme)
# Évaluation pour le locuteur : F6 (English - Femme)
# Évaluation pour le locuteur : F8 (English - Femme)
# Évaluation pour le locuteur : F9 (English - Femme)
# Évaluation pour le locuteur : F1 (English - Femme)
# Évaluation pour le locuteur : F10 (English - Femme)
# Évaluation des modèles avec 64 composants.
# Évaluation pour le locuteur : H13 (English - Homme)
# Évaluation pour le locuteur : H14 (English - Homme)
# Évaluation pour le locuteur : H12 (English - Homme)
# Évaluation pour le locuteur : H15 (English - Homme)
# Évaluation pour le locuteur : H16 (English - Homme)
# Évaluation pour le locuteur : H17 (English - Homme)
# Évaluation pour le locuteur : H18 (English - Homme)
# Évaluation pour le locuteur : H19 (English - Homme)
# Évaluation pour le locuteur : H2 (English - Homme)
# Évaluation pour le locuteur : H3 (English - Homme)
# Évaluation pour le locuteur : H4 (English - Homme)
# Évaluation pour le locuteur : H6 (English - Homme)
# Évaluation pour le locuteur : H5 (English - Homme)
# Évaluation pour le locuteur : H7 (English - Homme)
# Évaluation pour le locuteur : H8 (English - Homme)
# Évaluation pour le locuteur : H9 (English - Homme)
# Évaluation pour le locuteur : H1 (English - Homme)
# Évaluation pour le locuteur : H11 (English - Homme)
# Évaluation pour le locuteur : H10 (English - Homme)
# Évaluation pour le locuteur : F12 (English - Femme)
# Évaluation pour le locuteur : F11 (English - Femme)
# Évaluation pour le locuteur : F13 (English - Femme)
# Évaluation pour le locuteur : F14 (English - Femme)
# Évaluation pour le locuteur : F15 (English - Femme)
# Évaluation pour le locuteur : F16 (English - Femme)
# Évaluation pour le locuteur : F17 (English - Femme)
# Évaluation pour le locuteur : F18 (English - Femme)
# Évaluation pour le locuteur : F19 (English - Femme)
# Évaluation pour le locuteur : F2 (English - Femme)
# Évaluation pour le locuteur : F20 (English - Femme)
# Évaluation pour le locuteur : F21 (English - Femme)
# Évaluation pour le locuteur : F3 (English - Femme)
# Évaluation pour le locuteur : F4 (English - Femme)
# Évaluation pour le locuteur : F5 (English - Femme)
# Évaluation pour le locuteur : F7 (English - Femme)
# Évaluation pour le locuteur : F6 (English - Femme)
# Évaluation pour le locuteur : F8 (English - Femme)
# Évaluation pour le locuteur : F9 (English - Femme)
# Évaluation pour le locuteur : F1 (English - Femme)
# Évaluation pour le locuteur : F10 (English - Femme)
# Évaluation des modèles avec 128 composants.
# Évaluation pour le locuteur : H13 (English - Homme)
# Évaluation pour le locuteur : H14 (English - Homme)
# Évaluation pour le locuteur : H12 (English - Homme)
# Évaluation pour le locuteur : H15 (English - Homme)
# Évaluation pour le locuteur : H16 (English - Homme)
# Évaluation pour le locuteur : H17 (English - Homme)
# Évaluation pour le locuteur : H18 (English - Homme)
# Évaluation pour le locuteur : H19 (English - Homme)
# Évaluation pour le locuteur : H2 (English - Homme)
# Évaluation pour le locuteur : H3 (English - Homme)
# Évaluation pour le locuteur : H4 (English - Homme)
# Évaluation pour le locuteur : H6 (English - Homme)
# Évaluation pour le locuteur : H5 (English - Homme)
# Évaluation pour le locuteur : H7 (English - Homme)
# Évaluation pour le locuteur : H8 (English - Homme)
# Évaluation pour le locuteur : H9 (English - Homme)
# Évaluation pour le locuteur : H1 (English - Homme)
# Évaluation pour le locuteur : H11 (English - Homme)
# Évaluation pour le locuteur : H10 (English - Homme)
# Évaluation pour le locuteur : F12 (English - Femme)
# Évaluation pour le locuteur : F11 (English - Femme)
# Évaluation pour le locuteur : F13 (English - Femme)
# Évaluation pour le locuteur : F14 (English - Femme)
# Évaluation pour le locuteur : F15 (English - Femme)
# Évaluation pour le locuteur : F16 (English - Femme)
# Évaluation pour le locuteur : F17 (English - Femme)
# Évaluation pour le locuteur : F18 (English - Femme)
# Évaluation pour le locuteur : F19 (English - Femme)
# Évaluation pour le locuteur : F2 (English - Femme)
# Évaluation pour le locuteur : F20 (English - Femme)
# Évaluation pour le locuteur : F21 (English - Femme)
# Évaluation pour le locuteur : F3 (English - Femme)
# Évaluation pour le locuteur : F4 (English - Femme)
# Évaluation pour le locuteur : F5 (English - Femme)
# Évaluation pour le locuteur : F7 (English - Femme)
# Évaluation pour le locuteur : F6 (English - Femme)
# Évaluation pour le locuteur : F8 (English - Femme)
# Évaluation pour le locuteur : F9 (English - Femme)
# Évaluation pour le locuteur : F1 (English - Femme)
# Évaluation pour le locuteur : F10 (English - Femme)

# %%
def afficher_precision_locuteur(resultats_path, liste_nb_composants):
    # Parcourir les langues dans le répertoire des résultats
    for langue_cible in os.listdir(resultats_path):
        # Parcourir les genres (homme/femme) dans chaque langue
        for genre_cible in os.listdir(os.path.join(resultats_path, langue_cible)):
            # Parcourir les locuteurs dans chaque genre
            for locuteur_cible in os.listdir(os.path.join(resultats_path, langue_cible, genre_cible)):
                print(f"Le locuteur {locuteur_cible} ({langue_cible} - {genre_cible}) :")

                # Pour chaque nombre de composants GMM
                for n_components in liste_nb_composants:
                    total_tests = 0
                    correct_predictions = 0

                    # Chemin vers les résultats pour chaque locuteur et nombre de composants
                    locuteur_results_path = os.path.join(resultats_path, langue_cible, genre_cible, locuteur_cible)

                    # Vérifier si le dossier existe
                    if os.path.exists(locuteur_results_path):
                        for file in os.listdir(locuteur_results_path):
                            if file.startswith(f"Test_GMM_{n_components}_{langue_cible}_{genre_cible}_{locuteur_cible}") and file.endswith(".txt"):  # les fichiers correspondant
                                file_path = os.path.join(locuteur_results_path, file)
                                with open(file_path, 'r') as f:
                                    # Sauter l'en-tête
                                    next(f)

                                    # Lire chaque ligne du fichier
                                    for line in f:
                                        # Extraire les informations de la ligne
                                        parts = line.strip().split("\t")
                                        seg_name, locuteur_cible_file, score_max, decision = parts

                                        # Comparer le locuteur cible avec le locuteur prédit
                                        if locuteur_cible_file == locuteur_cible:
                                            total_tests += 1
                                            if decision == "oui":  # Si la décision est "oui", c'est une bonne prédiction
                                                correct_predictions += 1

                        # Calculer et afficher la précision pour le modèle GMM avec n_components
                        if total_tests > 0:
                            precision = (correct_predictions / total_tests) * 100
                            print(f"   - La précision du modèle GMM {n_components} : {precision:.2f}%")
                        else:
                            print(f"   - Aucun test trouvé pour le modèle GMM {n_components}.")
                    else:
                        print(f"   - Aucun fichier trouvé pour le locuteur {locuteur_cible}.")

# Liste des composants GMM à tester
liste_nb_composants = [8, 16, 32, 64, 128]

# Appeler la fonction pour afficher les précisions
afficher_precision_locuteur('/content/drive/My Drive/Reconnaissance/Results_GMM/R-Locuteur', liste_nb_composants)
# Out:
# Le locuteur H1 (French - Homme) :
#    - La précision du modèle GMM 8 : 0.00%
#    - La précision du modèle GMM 16 : 0.00%
#    - La précision du modèle GMM 32 : 0.00%
#    - La précision du modèle GMM 64 : 0.00%
#    - La précision du modèle GMM 128 : 0.00%
# Le locuteur H2 (French - Homme) :
#    - La précision du modèle GMM 8 : 0.00%
#    - La précision du modèle GMM 16 : 0.00%
#    - La précision du modèle GMM 32 : 0.00%
#    - La précision du modèle GMM 64 : 0.00%
#    - La précision du modèle GMM 128 : 0.00%
# Le locuteur H3 (French - Homme) :
#    - La précision du modèle GMM 8 : 0.00%
#    - La précision du modèle GMM 16 : 0.00%
#    - La précision du modèle GMM 32 : 0.00%
#    - La précision du modèle GMM 64 : 0.00%
#    - La précision du modèle GMM 128 : 0.00%
# Le locuteur F1 (French - Femme) :
#    - La précision du modèle GMM 8 : 0.00%
#    - La précision du modèle GMM 16 : 0.00%
#    - La précision du modèle GMM 32 : 0.00%
#    - La précision du modèle GMM 64 : 0.00%
#    - La précision du modèle GMM 128 : 0.00%
# Le locuteur F4 (French - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F3 (French - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F5 (French - Femme) :
#    - La précision du modèle GMM 8 : 0.00%
#    - La précision du modèle GMM 16 : 0.00%
#    - La précision du modèle GMM 32 : 0.00%
#    - La précision du modèle GMM 64 : 0.00%
#    - La précision du modèle GMM 128 : 0.00%
# Le locuteur F6 (French - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H12 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H1 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H10 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H11 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H13 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H4 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H2 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 90.91%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H3 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H5 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H6 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 85.71%
#    - La précision du modèle GMM 64 : 57.14%
#    - La précision du modèle GMM 128 : 42.86%
# Le locuteur H7 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 46.15%
#    - La précision du modèle GMM 16 : 38.46%
#    - La précision du modèle GMM 32 : 76.92%
#    - La précision du modèle GMM 64 : 92.31%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H8 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 90.00%
#    - La précision du modèle GMM 16 : 90.00%
#    - La précision du modèle GMM 32 : 90.00%
#    - La précision du modèle GMM 64 : 90.00%
#    - La précision du modèle GMM 128 : 90.00%
# Le locuteur H9 (Spanish - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F1 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F2 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 95.00%
#    - La précision du modèle GMM 16 : 95.00%
#    - La précision du modèle GMM 32 : 95.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F3 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 95.24%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F4 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F5 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F6 (Spanish - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H13 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H14 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H12 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H15 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H16 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H17 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H18 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H19 (English - Homme) :
#    - La précision du modèle GMM 8 : 96.00%
#    - La précision du modèle GMM 16 : 96.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H2 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H3 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H4 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H6 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H5 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H7 (English - Homme) :
#    - La précision du modèle GMM 8 : 97.06%
#    - La précision du modèle GMM 16 : 97.06%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H8 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H9 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H1 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H11 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur H10 (English - Homme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F12 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F11 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F13 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F14 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F15 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F16 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F17 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F18 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F19 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F2 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F20 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F21 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F3 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F4 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F5 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F7 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F6 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F8 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F9 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F1 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%
# Le locuteur F10 (English - Femme) :
#    - La précision du modèle GMM 8 : 100.00%
#    - La précision du modèle GMM 16 : 100.00%
#    - La précision du modèle GMM 32 : 100.00%
#    - La précision du modèle GMM 64 : 100.00%
#    - La précision du modèle GMM 128 : 100.00%

# %%
# dossier_GMMs_Locuteur = '/content/drive/My Drive/Reconnaissance/Models_GMM/R-Locuteur'
# modeles_GMM['French']['Femme']['F1']
